# %%
import torch 
import matplotlib.pyplot as plt

# %%
B,C,H,W = 128, 1, 32,32
batch = torch.rand((B,C,H,W))
pad_size = H//2

# %%
reflayer = torch.nn.ReflectionPad2d(padding=pad_size)

# %%
batch_padded = reflayer(batch)
batch_padded.shape
# Out:
# torch.Size([128, 1, 64, 64])

# %%
fig,ax = plt.subplots(ncols=3, figsize=(4*3,4))
ax[0].imshow(batch[0,0,:,:])
ax[1].imshow(batch_padded[0,0,pad_size : H + pad_size , pad_size : H + pad_size])
ax[2].imshow(batch_padded[0,0,:,:])
plt.show()
