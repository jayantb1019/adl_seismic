# %%
import os
import numpy as np 
from glob import glob 

BASE_DIR = '../data/Netherlands_F3_Interpretation'
INLINES_DIR = 'inlines'
CROSSLINES_DIR = 'crosslines'
INLINE_PATCHES_DIR = 'tiles_inlines'
CROSSLINE_PATCHES_DIR = 'tiles_crosslines'
MASKS_DIR = 'masks' # contain masks for all inlines and cross lines

# %%
inline_patches = sorted(glob(os.path.join(BASE_DIR, INLINES_DIR, '*')))
inline_patches
# Out:
# ['../data/Netherlands_F3_Interpretation/inlines/inline_100.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_101.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_102.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_103.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_104.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_105.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_106.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_107.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_108.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_109.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_110.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_111.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_112.tiff',
#  '../data/Netherlands_F3_Interpretation/inlines/inline_113.tiff',
# ...
